# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from collections import defaultdict
from datetime import datetime 
from tqdm import tqdm_notebook
from collections import Counter
from bs4 import BeautifulSoup as bs
from tqdm import tqdm_notebook
from selenium.common.exceptions import NoSuchElementException

import urllib.request
import urllib.parse
import lxml.html
import requests
import pandas as pd
import time
import math
import re
import random

# word2vec
from gensim.models.word2vec import Word2Vec
import gensim 
import gensim.models as g

# %%
# driver path
path = 'C:/Users/Administrator/chromedriver'
driver = webdriver.Chrome(path)

# %%
# url 데이터프레임 생성
urlDf = pd.DataFrame(data = {'유튜버': ['디렉터파이','디렉터파이','디렉터파이','디렉터파이','디렉터파이','이사배','디렉터파이','회사원a','회사원a','회사원a'],
                              '제목': ['(*Eng) 내 피부가 이랬어?! 민감, 지성, 건성 에센스 BEST 궁합 찾는 법 by 디렉터파이',
                                    '[디파GO]민감 건성, 보습과 탄력? 화장품 바르는 4가지 방법(디렉터파이 피부 측정 결과?)',
                                     '(**Eng.)여드름, 좁쌀, 각질 부자 모여! 피부타입별 성분 궁합& 착한 크림들끼리 대격돌, 과연 승자는? by 디렉터파이',
                                     '(*Eng)피부타입별 토너 사용법 따로 있다? 효과 검증 화장솜 궁합까지. by 디렉터파이',
                                     '속건조 해결?! 지성, 수부지 민감한 피부 위한 기초 스킨케어 by. 디렉터파이',
                                     '[Eng] 민감피부🤦🏻‍♀ 나의 하루종일 피부진정방법🍀 Calming Skincare Routine l 이사배(RISABAE Makeup)',
                                     '(*Eng) 국내 더마 코스메틱 Top5 성분 효과 검증 by 디렉터파이',
                                     '민감피부 되돌리기 3일 프로젝트',
                                     '살아남아! 이 각박한 민감피부 권하는 세상에서!! feat.더마토리',
                                     '기초 바르는 방법만 바꿔서 피부 탄력 살리기!! feat.밀도케어'
                                    ],
                              'url': ['https://www.youtube.com/watch?v=YkX9SA166RM&t=51s',
                                     'https://www.youtube.com/watch?v=6zti2UXhQ3A',
                                     'https://www.youtube.com/watch?v=q12lCuRff34',
                                      'https://www.youtube.com/watch?v=C8wXn0Xdp1c',
                                      'https://www.youtube.com/watch?v=N1M2ocbcHb0',
                                      'https://www.youtube.com/watch?v=xsBKNABqi5E',
                                      'https://www.youtube.com/watch?v=_sejSV5yXro',
                                      'https://www.youtube.com/watch?v=Wf90OkNhAGY&t=3s',
                                      'https://www.youtube.com/watch?v=K0Q6-r1aHRE',
                                      'https://www.youtube.com/watch?v=8aBYjw2C8us'
                                     ],
                              '조회수': [317550,
                                      183588,
                                      1432136,
                                      961828,
                                      943392,
                                      456728,
                                      184022,
                                      1416944,
                                      167386,
                                      674600
                                      
                                     ],
                              '날짜':['2018-06-08',
                                   '2017-09-01',
                                   '2017-10-20',
                                    '2018-05-04',
                                   '2017-08-11',
                                   '2018-06-09',
                                   '2018-10-29',
                                   '2016-12-28',
                                   '2019-03-17',
                                   '2019-01-22'],
                              '댓글수': [302,
                                     177,
                                     1080,
                                      849,
                                     786,
                                     426,
                                     282,
                                      1383,
                                     297, 
                                      976]})

# %%
urlDf
# Out:
#      유튜버                                                 제목  \
# 0  디렉터파이  (*Eng) 내 피부가 이랬어?! 민감, 지성, 건성 에센스 BEST 궁합 찾는 법...
# 1  디렉터파이  [디파GO]민감 건성, 보습과 탄력? 화장품 바르는 4가지 방법(디렉터파이 피부 측...
# 2  디렉터파이  (**Eng.)여드름, 좁쌀, 각질 부자 모여! 피부타입별 성분 궁합& 착한 크림들...
# 3  디렉터파이  (*Eng)피부타입별 토너 사용법 따로 있다? 효과 검증 화장솜 궁합까지. by 디...
# 4  디렉터파이       속건조 해결?! 지성, 수부지 민감한 피부 위한 기초 스킨케어 by. 디렉터파이
# 5    이사배  [Eng] 민감피부🤦🏻‍♀ 나의 하루종일 피부진정방법🍀 Calming Skincar...
# 6  디렉터파이           (*Eng) 국내 더마 코스메틱 Top5 성분 효과 검증 by 디렉터파이
# 7   회사원a                                  민감피부 되돌리기 3일 프로젝트
# 8   회사원a              살아남아! 이 각박한 민감피부 권하는 세상에서!! feat.더마토리
# 9   회사원a               기초 바르는 방법만 바꿔서 피부 탄력 살리기!! feat.밀도케어
#
#                                                  url      조회수          날짜  \
# 0  https://www.youtube.com/watch?v=YkX9SA166RM&t=51s   317550  2018-06-08
# 1        https://www.youtube.com/watch?v=6zti2UXhQ3A   183588  2017-09-01
# 2        https://www.youtube.com/watch?v=q12lCuRff34  1432136  2017-10-20
# 3        https://www.youtube.com/watch?v=C8wXn0Xdp1c   961828  2018-05-04
# 4        https://www.youtube.com/watch?v=N1M2ocbcHb0   943392  2017-08-11
# 5        https://www.youtube.com/watch?v=xsBKNABqi5E   456728  2018-06-09
# 6        https://www.youtube.com/watch?v=_sejSV5yXro   184022  2018-10-29
# 7   https://www.youtube.com/watch?v=Wf90OkNhAGY&t=3s  1416944  2016-12-28
# 8        https://www.youtube.com/watch?v=K0Q6-r1aHRE   167386  2019-03-17
# 9        https://www.youtube.com/watch?v=8aBYjw2C8us   674600  2019-01-22
#
#     댓글수
# 0   302
# 1   177
# 2  1080
# 3   849
# 4   786
# 5   426
# 6   282
# 7  1383
# 8   297
# 9   976

# %%
urlDf.to_excel('피부진정,민감피부 컨텐츠.xlsx')

# %% [markdown]
# ## 잠재고객 url 리스트 만들기

# %%
len(urlDf.iloc[7:,])
# Out:
# 3

# %%
#reply_cnt = int(driver.find_element_by_css_selector('#count > yt-formatted-string').text[3:-1]) #댓글수
user_list = []
reply_list = []

for i in range(7,10):
    driver.get(urlDf.url[i])
    reply_cnt = urlDf.댓글수[i]

    start = datetime.now()
    batang = driver.find_element_by_css_selector("body") 
    while True : 
        now = datetime.now() 

        batang.send_keys(Keys.PAGE_DOWN)  
        time.sleep(1)

        # 더보기 클릭하는 반복문
        try:
            more_btns = driver.find_elements_by_xpath('//*[@id="more-replies"]')
            for more_btn in more_btns:
                try:
                    more_btn.click()
                    time.sleep(1)
                except:
                    pass            
        except:
            pass

        replys = driver.find_elements_by_css_selector('yt-formatted-string#content-text.style-scope.ytd-comment-renderer')
        check_cnt = len(replys) 
        if check_cnt == reply_cnt:
            break
        elif (now-start).seconds > 300:
            break
    
    time.sleep(2)

    # 댓글 단 사람들의 url
    user_urls = driver.find_elements_by_css_selector('#author-text')  
    time.sleep(2)
    for user_url in user_urls:
        user_list.append([user_url.text, user_url.get_attribute('href')])

    # 댓글 단 사람들의 댓글
    replys = driver.find_elements_by_css_selector('yt-formatted-string#content-text.style-scope.ytd-comment-renderer')
    time.sleep(2)
    for reply in replys:
        reply_list.append(reply.text)
        
    continue

# %%
replyDf = pd.DataFrame(reply_list, columns = ['댓글내용'])
replyDf.head()
# Out:
#                                                 댓글내용
# 0  민감할땐 팩하면 안 돼요..제일 심할땐 병원가서 한 3일은 약 먹고 바르시구요, 모...
# 1                               0:40썬글라스쫌 오래쓰셨나보네...
# 2                    전 일어나면 얼굴이 무거워질 정도로 기름이 올라와서...
# 3  대신 답변 죄송하지만 저도 그랬는데 그럴때마다 아침 세안을 열심히 해주는 것이 중요...
# 4                     @몽럠ᄒ 네 그래서 항상 세안 열심히 하고 있어요 ㅎㅎ

# %%
len(replyDf)
# Out:
# 2019

# %%
replyDf.to_excel('유튜브댓글(회사원추가).xlsx')

# %%
replyDf = pd.read_excel('유튜브댓글(회사원추가).xlsx', index_col=0)
replyDf.head()
# Out:
#                                                 댓글내용
# 0  민감할땐 팩하면 안 돼요..제일 심할땐 병원가서 한 3일은 약 먹고 바르시구요, 모...
# 1                               0:40썬글라스쫌 오래쓰셨나보네...
# 2                    전 일어나면 얼굴이 무거워질 정도로 기름이 올라와서...
# 3  대신 답변 죄송하지만 저도 그랬는데 그럴때마다 아침 세안을 열심히 해주는 것이 중요...
# 4                     @몽럠ᄒ 네 그래서 항상 세안 열심히 하고 있어요 ㅎㅎ

# %% [markdown]
# ## 댓글 분석

# %%
replyDf1 = pd.read_excel('유튜브댓글(회사원추가).xlsx', index_col=0)
replyDf1.head()
# Out:
#                                                 댓글내용
# 0  안녕하세요, 오늘 올라갈 영상은 내 피부타입 아는 법-기초(1편 에센스), (2편 ...
# 1               디렉터 파이 Do english subtitle please~🙏🏻
# 2                                       겨울버전도 해주세요ㅠㅠ
# 3                     코랑 이마엔 기름이많고 다른곳은 건조하면 수부지인가요?
# 4  디렉터 파이 토너나 다른 것들은 안바르고 에센스 수분크림만 발라도될까요?? 고수님들...

# %%
replyDf.head()
# Out:
#                                                 댓글내용
# 0  민감할땐 팩하면 안 돼요..제일 심할땐 병원가서 한 3일은 약 먹고 바르시구요, 모...
# 1                               0:40썬글라스쫌 오래쓰셨나보네...
# 2                    전 일어나면 얼굴이 무거워질 정도로 기름이 올라와서...
# 3  대신 답변 죄송하지만 저도 그랬는데 그럴때마다 아침 세안을 열심히 해주는 것이 중요...
# 4                     @몽럠ᄒ 네 그래서 항상 세안 열심히 하고 있어요 ㅎㅎ

# %%
replyTot = pd.concat([replyDf1,replyDf], axis=0)
replyTot.head()
# Out:
#                                                 댓글내용
# 0  안녕하세요, 오늘 올라갈 영상은 내 피부타입 아는 법-기초(1편 에센스), (2편 ...
# 1               디렉터 파이 Do english subtitle please~🙏🏻
# 2                                       겨울버전도 해주세요ㅠㅠ
# 3                     코랑 이마엔 기름이많고 다른곳은 건조하면 수부지인가요?
# 4  디렉터 파이 토너나 다른 것들은 안바르고 에센스 수분크림만 발라도될까요?? 고수님들...

# %%
from worin.tag import Worin

# %%
tagger= Worin()
def get_nouns(text):
    try: # 에러가 발생하지 않을 경우
        nouns = tagger.nouns(text)
        nouns = [word for word in nouns if len(word) > 1]
        return nouns
    except: # 에러 발생
        return ["error"]

# %%
## CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=1000, tokenizer=get_nouns)

# %%
## TDM
tdm = cv.fit_transform(replyTot['댓글내용'])

# %%
for i, n in sorted(zip(tdm[0].indices, tdm[0].data)):
    print(words[i], n)
# Out:
# 글리세린 1
# 나중 2
# 모공 1
# 밀리 1
# 바이 1
# 성인 1
# 세범 1
# 순정 1
# 업로드 1
# 여드름성 1
# 여자 1
# 옛날 1
# 저기 1
# 젤크림 1
# 평소 1
# 피부관리 2
# 피부톤 1
# 피분데 2
# 필요 1
# 홍조 1
# 환경 1

# %%
## TF-IDF로 변환
from sklearn.feature_extraction.text import TfidfTransformer
tfidf = TfidfTransformer()
tdm2 = tfidf.fit_transform(tdm)
words = cv.get_feature_names()

# %%
for i, n in sorted(zip(tdm2[0].indices, tdm2[0].data)):
    print(words[i], n)
# Out:
# 궁합 0.2509862118654019
# 기초 0.32922908410022905
# 메이크업 0.19192166867018726
# 미백 0.23610801067113246
# 민감 0.13583698207152792
# 선크림 0.18883015682120122
# 성분 0.12742872899747465
# 수분크림 0.17234519287722158
# 에센스 0.18440757055380347
# 여름 0.1882445102256253
# 영상 0.10846189613380687
# 오늘 0.16376199447629808
# 장벽 0.2549524178397855
# 제대 0.24743831972340172
# 편도 0.2509862118654019
# 피부 0.20077526362042628
# 피부장벽 0.2115854308713144
# 피부타 0.3591776340112068
# 필요 0.1778391335658284
# 홍조 0.18654631021037205
# 회복 0.24129885452974917

# %%
from sklearn.externals import joblib

# %%
## 저장
from sklearn.externals import joblib
with open('dermatory_reply_tdm2_galarygirl.pkl', 'wb') as f:
    joblib.dump({'vectorizer': cv, 'tdm': tdm, 'tfidf': tdm2}, f)

# %%
with open('dermatory_reply_tdm2_galarygirl.pkl', 'rb') as f:
    data = joblib.load(f)
locals().update(data)

# %%
## 단어빈도표
wordcount = pd.DataFrame(
    {'단어': cv.get_feature_names(),
     '빈도': tdm2.sum(axis=0).flat
    }
)
wordcount.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\dtypes.py:458: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if string == 'category':
#     단어         빈도
# 0   가격  16.219409
# 1  가격대   2.133321
# 2   가능   7.006937
# 3   가볍   2.521762
# 4   가시   2.995779

# %%
wordcount.sort_values('빈도', ascending=False).to_excel('댓글분석(회사원추가).xlsx')

# %% [markdown]
# ### 2. 워드임베딩

# %%
## Worin 형태소 분석기 사용
tagger= Worin()
def get_nouns(text):
    try: # 에러가 발생하지 않을 경우
        nouns = tagger.nouns(text)
        nouns = [word for word in nouns if len(word) > 1]
        return nouns
    except: # 에러 발생
        return ["error"]

# %%
documents = []
for i in range(len(replyDf.iloc[i,0])):
    documents.append(get_nouns(replyDf.iloc[i,0]))

# %%
documents[0]
# Out:
# ['민감',
#  '제일',
#  '병원가서',
#  '모델링팩',
#  '마스크',
#  '민감',
#  '쥐약',
#  '기본',
#  '충실',
#  '수분크림',
#  '천연',
#  '오일',
#  '천연',
#  '성분',
#  '열감',
#  '차갑',
#  '세수',
#  '마스크',
#  '얼굴',
#  '쥐약',
#  '피부염',
#  '피부',
#  '혈관',
#  '확장',
#  '긋불',
#  '고생',
#  '깨달음']

# %%
model = Word2Vec(documents,         # 리스트 형태
                 sg=1,         # 0: CBOW, 1: Skip-gram
                 size=300,     # 벡터 크기
                 window=10,     # 고려할 앞뒤 폭(앞뒤 3단어)
                 min_count=1,  # 사용할 단어의 최소 빈도(3회 이하 단어 무시)
                 workers=4)    # 동시에 처리할 작업 수(코어 수와 비슷하게 설정)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py:743: UserWarning: C extension not loaded, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   "C extension not loaded, training will be slow. "
# W0822 17:08:54.724946   520 base_any2vec.py:1386] under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
len(model.wv.vocab)
# Out:
# 317

# %%
model.wv.vocab
# Out:
# {'민감': <gensim.models.keyedvectors.Vocab at 0x18f979e8>,
#  '제일': <gensim.models.keyedvectors.Vocab at 0x188bd550>,
#  '병원가서': <gensim.models.keyedvectors.Vocab at 0x188bdcc0>,
#  '모델링팩': <gensim.models.keyedvectors.Vocab at 0x188bdc50>,
#  '마스크': <gensim.models.keyedvectors.Vocab at 0x188bddd8>,
#  '쥐약': <gensim.models.keyedvectors.Vocab at 0x188bdc18>,
#  '기본': <gensim.models.keyedvectors.Vocab at 0x188bd4e0>,
#  '충실': <gensim.models.keyedvectors.Vocab at 0x188bdd68>,
#  '수분크림': <gensim.models.keyedvectors.Vocab at 0x188bdb38>,
#  '천연': <gensim.models.keyedvectors.Vocab at 0x188bdeb8>,
#  '오일': <gensim.models.keyedvectors.Vocab at 0x188bd668>,
#  '성분': <gensim.models.keyedvectors.Vocab at 0x188bdba8>,
#  '열감': <gensim.models.keyedvectors.Vocab at 0x188bdf98>,
#  '차갑': <gensim.models.keyedvectors.Vocab at 0x188bdf60>,
#  '세수': <gensim.models.keyedvectors.Vocab at 0x188bdef0>,
#  '얼굴': <gensim.models.keyedvectors.Vocab at 0x188bdf28>,
#  '피부염': <gensim.models.keyedvectors.Vocab at 0x188bd5f8>,
#  '피부': <gensim.models.keyedvectors.Vocab at 0x188bd6a0>,
#  '혈관': <gensim.models.keyedvectors.Vocab at 0x188bd630>,
#  '확장': <gensim.models.keyedvectors.Vocab at 0x188bd1d0>,
#  '긋불': <gensim.models.keyedvectors.Vocab at 0x188bd160>,
#  '고생': <gensim.models.keyedvectors.Vocab at 0x188bd198>,
#  '깨달음': <gensim.models.keyedvectors.Vocab at 0x188bd400>,
#  '썬글라스쫌': <gensim.models.keyedvectors.Vocab at 0x188bd438>,
#  '오래': <gensim.models.keyedvectors.Vocab at 0x188bd470>,
#  '정도': <gensim.models.keyedvectors.Vocab at 0x188bde48>,
#  '기름': <gensim.models.keyedvectors.Vocab at 0x188bdda0>,
#  '대신': <gensim.models.keyedvectors.Vocab at 0x188bd710>,
#  '답변': <gensim.models.keyedvectors.Vocab at 0x188bd748>,
#  '죄송': <gensim.models.keyedvectors.Vocab at 0x188bd780>,
#  '아침': <gensim.models.keyedvectors.Vocab at 0x188bd7b8>,
#  '세안': <gensim.models.keyedvectors.Vocab at 0x188bd7f0>,
#  '중요': <gensim.models.keyedvectors.Vocab at 0x188bd828>,
#  '열심': <gensim.models.keyedvectors.Vocab at 0x188bd860>,
#  '지성': <gensim.models.keyedvectors.Vocab at 0x188bd898>,
#  '자영화좀': <gensim.models.keyedvectors.Vocab at 0x188bd8d0>,
#  '튀김': <gensim.models.keyedvectors.Vocab at 0x188bd908>,
#  '시간': <gensim.models.keyedvectors.Vocab at 0x188bd940>,
#  '후면': <gensim.models.keyedvectors.Vocab at 0x188bd978>,
#  '실례': <gensim.models.keyedvectors.Vocab at 0x188bd9b0>,
#  '스트레스': <gensim.models.keyedvectors.Vocab at 0x188bd9e8>,
#  '누구': <gensim.models.keyedvectors.Vocab at 0x188bda20>,
#  '관리': <gensim.models.keyedvectors.Vocab at 0x188bda58>,
#  '김김김': <gensim.models.keyedvectors.Vocab at 0x188bda90>,
#  '피부얘기': <gensim.models.keyedvectors.Vocab at 0x188bdfd0>,
#  '건데': <gensim.models.keyedvectors.Vocab at 0x16e2d390>,
#  '밥말아': <gensim.models.keyedvectors.Vocab at 0x16e2d2b0>,
#  '고민': <gensim.models.keyedvectors.Vocab at 0x16e2d358>,
#  '간사': <gensim.models.keyedvectors.Vocab at 0x16e2d400>,
#  '광고': <gensim.models.keyedvectors.Vocab at 0x1a1e7438>,
#  '회사원': <gensim.models.keyedvectors.Vocab at 0x1a1e7400>,
#  '영상인줄알고': <gensim.models.keyedvectors.Vocab at 0x18728278>,
#  '화이트': <gensim.models.keyedvectors.Vocab at 0x187284a8>,
#  '태닝': <gensim.models.keyedvectors.Vocab at 0x187289b0>,
#  '초등학생': <gensim.models.keyedvectors.Vocab at 0x18728ac8>,
#  '화장': <gensim.models.keyedvectors.Vocab at 0x18728940>,
#  '선크림': <gensim.models.keyedvectors.Vocab at 0x18728128>,
#  '대충': <gensim.models.keyedvectors.Vocab at 0x18728048>,
#  '엄마': <gensim.models.keyedvectors.Vocab at 0x18728358>,
#  '거바르': <gensim.models.keyedvectors.Vocab at 0x187280b8>,
#  '난후': <gensim.models.keyedvectors.Vocab at 0x187282e8>,
#  '대신답변': <gensim.models.keyedvectors.Vocab at 0x187286a0>,
#  '자신': <gensim.models.keyedvectors.Vocab at 0x187284e0>,
#  '감사': <gensim.models.keyedvectors.Vocab at 0x18728e48>,
#  '다음': <gensim.models.keyedvectors.Vocab at 0x18728c50>,
#  '그거': <gensim.models.keyedvectors.Vocab at 0x18728cf8>,
#  '병원': <gensim.models.keyedvectors.Vocab at 0x18728cc0>,
#  '샘플': <gensim.models.keyedvectors.Vocab at 0x18728860>,
#  '로션': <gensim.models.keyedvectors.Vocab at 0x18728978>,
#  '연고': <gensim.models.keyedvectors.Vocab at 0x18728ef0>,
#  '하루': <gensim.models.keyedvectors.Vocab at 0x18728eb8>,
#  '기계': <gensim.models.keyedvectors.Vocab at 0x18728a90>,
#  '전체': <gensim.models.keyedvectors.Vocab at 0x18728f98>,
#  '뒤집': <gensim.models.keyedvectors.Vocab at 0x18728f28>,
#  '가야': <gensim.models.keyedvectors.Vocab at 0x18728da0>,
#  '흑흑': <gensim.models.keyedvectors.Vocab at 0x18728d30>,
#  '종종': <gensim.models.keyedvectors.Vocab at 0x18728ba8>,
#  '가시': <gensim.models.keyedvectors.Vocab at 0x18728b38>,
#  '추천드': <gensim.models.keyedvectors.Vocab at 0x18728a58>,
#  '거품': <gensim.models.keyedvectors.Vocab at 0x187289e8>,
#  '제품명좀': <gensim.models.keyedvectors.Vocab at 0x18728908>,
#  '미샤': <gensim.models.keyedvectors.Vocab at 0x18728898>,
#  '이소': <gensim.models.keyedvectors.Vocab at 0x18728748>,
#  '천원': <gensim.models.keyedvectors.Vocab at 0x187286d8>,
#  '저거': <gensim.models.keyedvectors.Vocab at 0x18728588>,
#  '평생': <gensim.models.keyedvectors.Vocab at 0x18728518>,
#  '간지': <gensim.models.keyedvectors.Vocab at 0x18728fd0>,
#  '약타': <gensim.models.keyedvectors.Vocab at 0x18728f60>,
#  '속상': <gensim.models.keyedvectors.Vocab at 0x188bdd30>,
#  '약드': <gensim.models.keyedvectors.Vocab at 0x188bdc88>,
#  '시면': <gensim.models.keyedvectors.Vocab at 0x188bdb70>,
#  '체질': <gensim.models.keyedvectors.Vocab at 0x188bdcf8>,
#  '건성': <gensim.models.keyedvectors.Vocab at 0x1875e828>,
#  '건조': <gensim.models.keyedvectors.Vocab at 0x1875e3c8>,
#  '겨울': <gensim.models.keyedvectors.Vocab at 0x1875eb38>,
#  '작년각질': <gensim.models.keyedvectors.Vocab at 0x1875ecf8>,
#  '제거': <gensim.models.keyedvectors.Vocab at 0x1875ec88>,
#  '가도': <gensim.models.keyedvectors.Vocab at 0x1875e128>,
#  '호전': <gensim.models.keyedvectors.Vocab at 0x1875e2e8>,
#  '기미': <gensim.models.keyedvectors.Vocab at 0x1875ea58>,
#  '보여': <gensim.models.keyedvectors.Vocab at 0x1875ef28>,
#  '아직': <gensim.models.keyedvectors.Vocab at 0x1875e208>,
#  '계속': <gensim.models.keyedvectors.Vocab at 0x1875e0b8>,
#  '식염수': <gensim.models.keyedvectors.Vocab at 0x18afd518>,
#  '구입': <gensim.models.keyedvectors.Vocab at 0x18afdf98>,
#  '둔감러': <gensim.models.keyedvectors.Vocab at 0x18f97d30>,
#  '얼마': <gensim.models.keyedvectors.Vocab at 0x18f97940>,
#  '상상': <gensim.models.keyedvectors.Vocab at 0x18f977f0>,
#  '동안': <gensim.models.keyedvectors.Vocab at 0x18f97ef0>,
#  '메이크업': <gensim.models.keyedvectors.Vocab at 0x18f97320>,
#  '경우': <gensim.models.keyedvectors.Vocab at 0x18f97630>,
#  '손안대면': <gensim.models.keyedvectors.Vocab at 0x18f971d0>,
#  '나이': <gensim.models.keyedvectors.Vocab at 0x18f97390>,
#  '시험때문': <gensim.models.keyedvectors.Vocab at 0x18f979b0>,
#  '프사': <gensim.models.keyedvectors.Vocab at 0x18f97eb8>,
#  '정우': <gensim.models.keyedvectors.Vocab at 0x18f97fd0>,
#  '수딩젤': <gensim.models.keyedvectors.Vocab at 0x18f97cc0>,
#  '부위': <gensim.models.keyedvectors.Vocab at 0x18f97860>,
#  '근데': <gensim.models.keyedvectors.Vocab at 0x18f97b00>,
#  '발라': <gensim.models.keyedvectors.Vocab at 0x18f97cf8>,
#  '루순': <gensim.models.keyedvectors.Vocab at 0x18f97400>,
#  '학생': <gensim.models.keyedvectors.Vocab at 0x18f97a58>,
#  '독성': <gensim.models.keyedvectors.Vocab at 0x18f544e0>,
#  '진정팩조': <gensim.models.keyedvectors.Vocab at 0x141d57b8>,
#  '바세린': <gensim.models.keyedvectors.Vocab at 0x19584278>,
#  '조금': <gensim.models.keyedvectors.Vocab at 0x18f6ba20>,
#  '난리': <gensim.models.keyedvectors.Vocab at 0x18f6bac8>,
#  '티트리': <gensim.models.keyedvectors.Vocab at 0x18af0d68>,
#  '성분등': <gensim.models.keyedvectors.Vocab at 0x18af0da0>,
#  '자극': <gensim.models.keyedvectors.Vocab at 0x18af0cf8>,
#  '사용': <gensim.models.keyedvectors.Vocab at 0x18af0a20>,
#  '로마티카': <gensim.models.keyedvectors.Vocab at 0x18af08d0>,
#  '시드물': <gensim.models.keyedvectors.Vocab at 0x18af07b8>,
#  '추천': <gensim.models.keyedvectors.Vocab at 0x18af06a0>,
#  '박지': <gensim.models.keyedvectors.Vocab at 0x18af0e10>,
#  '젤팩': <gensim.models.keyedvectors.Vocab at 0x18af03c8>,
#  '인공눈물': <gensim.models.keyedvectors.Vocab at 0x18af0550>,
#  '녀연': <gensim.models.keyedvectors.Vocab at 0x18af02e8>,
#  '코세척': <gensim.models.keyedvectors.Vocab at 0x18af0630>,
#  '멸균식염수': <gensim.models.keyedvectors.Vocab at 0x18af0160>,
#  '렌즈세척': <gensim.models.keyedvectors.Vocab at 0x18af0278>,
#  '여러분': <gensim.models.keyedvectors.Vocab at 0x18fa1e80>,
#  '마스크백': <gensim.models.keyedvectors.Vocab at 0x18b03c50>,
#  '사람피부': <gensim.models.keyedvectors.Vocab at 0x18b03be0>,
#  '사바사': <gensim.models.keyedvectors.Vocab at 0x18b03c88>,
#  '화장품': <gensim.models.keyedvectors.Vocab at 0x18b03e48>,
#  '메디힐': <gensim.models.keyedvectors.Vocab at 0x18b03b38>,
#  '방탄': <gensim.models.keyedvectors.Vocab at 0x16010be0>,
#  '인정': <gensim.models.keyedvectors.Vocab at 0x19be9cf8>,
#  '피부자극': <gensim.models.keyedvectors.Vocab at 0x19be95f8>,
#  '사람': <gensim.models.keyedvectors.Vocab at 0x19be9d68>,
#  '저정': <gensim.models.keyedvectors.Vocab at 0x19be9c88>,
#  '양호': <gensim.models.keyedvectors.Vocab at 0x19be9ac8>,
#  '클렌징폼': <gensim.models.keyedvectors.Vocab at 0x19be9f28>,
#  '가루': <gensim.models.keyedvectors.Vocab at 0x19be9eb8>,
#  '효소클렌져': <gensim.models.keyedvectors.Vocab at 0x19be97f0>,
#  '코코넛오일': <gensim.models.keyedvectors.Vocab at 0x19be9c18>,
#  '간단': <gensim.models.keyedvectors.Vocab at 0x19be9940>,
#  '세안후': <gensim.models.keyedvectors.Vocab at 0x19be9e48>,
#  '세면대': <gensim.models.keyedvectors.Vocab at 0x19be9908>,
#  '식초': <gensim.models.keyedvectors.Vocab at 0x187046d8>,
#  '한방울': <gensim.models.keyedvectors.Vocab at 0x187045f8>,
#  '헹구시': <gensim.models.keyedvectors.Vocab at 0x18704898>,
#  '안아파': <gensim.models.keyedvectors.Vocab at 0x18704f98>,
#  '단계': <gensim.models.keyedvectors.Vocab at 0x187040b8>,
#  '진정': <gensim.models.keyedvectors.Vocab at 0x18704eb8>,
#  '아예': <gensim.models.keyedvectors.Vocab at 0x18704198>,
#  '진정관리': <gensim.models.keyedvectors.Vocab at 0x194f6828>,
#  '싱크': <gensim.models.keyedvectors.Vocab at 0x194f67f0>,
#  '립싱크인줄': <gensim.models.keyedvectors.Vocab at 0x18728e10>,
#  '생리': <gensim.models.keyedvectors.Vocab at 0x18728e80>,
#  '분명': <gensim.models.keyedvectors.Vocab at 0x18728dd8>,
#  '영상인': <gensim.models.keyedvectors.Vocab at 0x18728d68>,
#  '댓글': <gensim.models.keyedvectors.Vocab at 0x18728c18>,
#  '최근': <gensim.models.keyedvectors.Vocab at 0x18728c88>,
#  '영상': <gensim.models.keyedvectors.Vocab at 0x18728be0>,
#  '학기': <gensim.models.keyedvectors.Vocab at 0x18728b70>,
#  '인데': <gensim.models.keyedvectors.Vocab at 0x18728a20>,
#  '학기초': <gensim.models.keyedvectors.Vocab at 0x187288d0>,
#  '원인': <gensim.models.keyedvectors.Vocab at 0x187287b8>,
#  '졸업사진': <gensim.models.keyedvectors.Vocab at 0x18728780>,
#  '업사진': <gensim.models.keyedvectors.Vocab at 0x18728710>,
#  '전날': <gensim.models.keyedvectors.Vocab at 0x187285f8>,
#  '생각': <gensim.models.keyedvectors.Vocab at 0x18728668>,
#  '입학식인': <gensim.models.keyedvectors.Vocab at 0x187285c0>,
#  '생김': <gensim.models.keyedvectors.Vocab at 0x18728550>,
#  '띱박': <gensim.models.keyedvectors.Vocab at 0x18728198>,
#  '오앙': <gensim.models.keyedvectors.Vocab at 0x18728828>,
#  '원래': <gensim.models.keyedvectors.Vocab at 0x187283c8>,
#  '리바운드': <gensim.models.keyedvectors.Vocab at 0x18728b00>,
#  '현상': <gensim.models.keyedvectors.Vocab at 0x18728630>,
#  '예민': <gensim.models.keyedvectors.Vocab at 0x187287f0>,
#  '반복': <gensim.models.keyedvectors.Vocab at 0x19453278>,
#  '최대': <gensim.models.keyedvectors.Vocab at 0x19453128>,
#  '자기': <gensim.models.keyedvectors.Vocab at 0x19453860>,
#  '차즌': <gensim.models.keyedvectors.Vocab at 0x19453c50>,
#  '게중': <gensim.models.keyedvectors.Vocab at 0x194538d0>,
#  '소량': <gensim.models.keyedvectors.Vocab at 0x19453eb8>,
#  '걱정': <gensim.models.keyedvectors.Vocab at 0x19453e48>,
#  '지아': <gensim.models.keyedvectors.Vocab at 0x19453710>,
#  '제품': <gensim.models.keyedvectors.Vocab at 0x19453550>,
#  '비누랑': <gensim.models.keyedvectors.Vocab at 0x194532e8>,
#  '토너': <gensim.models.keyedvectors.Vocab at 0x194530f0>,
#  '말고': <gensim.models.keyedvectors.Vocab at 0x194536d8>,
#  '션등': <gensim.models.keyedvectors.Vocab at 0x19453320>,
#  '일후': <gensim.models.keyedvectors.Vocab at 0x19453518>,
#  '바꾸시': <gensim.models.keyedvectors.Vocab at 0x19453908>,
#  '에뛰드순정라': <gensim.models.keyedvectors.Vocab at 0x19453ef0>,
#  '저도': <gensim.models.keyedvectors.Vocab at 0x194534e0>,
#  '뒤집어': <gensim.models.keyedvectors.Vocab at 0x19453a58>,
#  '꾀나': <gensim.models.keyedvectors.Vocab at 0x19453cc0>,
#  '바꾸': <gensim.models.keyedvectors.Vocab at 0x19453ac8>,
#  '렌저': <gensim.models.keyedvectors.Vocab at 0x19453668>,
#  '습크': <gensim.models.keyedvectors.Vocab at 0x19453f98>,
#  '시카밤': <gensim.models.keyedvectors.Vocab at 0x19453f28>,
#  '에밀전': <gensim.models.keyedvectors.Vocab at 0x19453da0>,
#  '다화학성': <gensim.models.keyedvectors.Vocab at 0x19453d30>,
#  '화해': <gensim.models.keyedvectors.Vocab at 0x19453ba8>,
#  '개별구매': <gensim.models.keyedvectors.Vocab at 0x19453b38>,
#  '화농성': <gensim.models.keyedvectors.Vocab at 0x194539b0>,
#  '갑자기': <gensim.models.keyedvectors.Vocab at 0x19453940>,
#  '갈돈': <gensim.models.keyedvectors.Vocab at 0x194537b8>,
#  '오조': <gensim.models.keyedvectors.Vocab at 0x19453748>,
#  '억번': <gensim.models.keyedvectors.Vocab at 0x194535c0>,
#  '세상': <gensim.models.keyedvectors.Vocab at 0x19453470>,
#  '이니스프리': <gensim.models.keyedvectors.Vocab at 0x194533c8>,
#  '핑팩': <gensim.models.keyedvectors.Vocab at 0x19453358>,
#  '암것': <gensim.models.keyedvectors.Vocab at 0x194531d0>,
#  '효과': <gensim.models.keyedvectors.Vocab at 0x19453160>,
#  '유지': <gensim.models.keyedvectors.Vocab at 0x19453fd0>,
#  '부뒤집어': <gensim.models.keyedvectors.Vocab at 0x19453f60>,
#  '병원가': <gensim.models.keyedvectors.Vocab at 0x19453e10>,
#  '안대': <gensim.models.keyedvectors.Vocab at 0x19453e80>,
#  '최소한': <gensim.models.keyedvectors.Vocab at 0x19453dd8>,
#  '성현아': <gensim.models.keyedvectors.Vocab at 0x19453d68>,
#  '부모': <gensim.models.keyedvectors.Vocab at 0x19453c18>,
#  '생각좀': <gensim.models.keyedvectors.Vocab at 0x19453c88>,
#  '혐생': <gensim.models.keyedvectors.Vocab at 0x19453be0>,
#  '세타필': <gensim.models.keyedvectors.Vocab at 0x19453b70>,
#  '브랜드': <gensim.models.keyedvectors.Vocab at 0x19453a20>,
#  '평소': <gensim.models.keyedvectors.Vocab at 0x19453a90>,
#  '세균': <gensim.models.keyedvectors.Vocab at 0x194539e8>,
#  '적응': <gensim.models.keyedvectors.Vocab at 0x19453978>,
#  '동태': <gensim.models.keyedvectors.Vocab at 0x19453828>,
#  '확인': <gensim.models.keyedvectors.Vocab at 0x19453898>,
#  '미피': <gensim.models.keyedvectors.Vocab at 0x194537f0>,
#  '형관펜': <gensim.models.keyedvectors.Vocab at 0x19453780>,
#  '유해': <gensim.models.keyedvectors.Vocab at 0x19453630>,
#  '분때문': <gensim.models.keyedvectors.Vocab at 0x194536a0>,
#  '피지오겔': <gensim.models.keyedvectors.Vocab at 0x194535f8>,
#  '땡기': <gensim.models.keyedvectors.Vocab at 0x19453588>,
#  '성피부': <gensim.models.keyedvectors.Vocab at 0x19453438>,
#  '이여서': <gensim.models.keyedvectors.Vocab at 0x194534a8>,
#  '마자': <gensim.models.keyedvectors.Vocab at 0x19453400>,
#  '클렌징': <gensim.models.keyedvectors.Vocab at 0x19453390>,
#  '은혼': <gensim.models.keyedvectors.Vocab at 0x19453240>,
#  '얜가': <gensim.models.keyedvectors.Vocab at 0x194532b0>,
#  '히지카타': <gensim.models.keyedvectors.Vocab at 0x19453208>,
#  '토시': <gensim.models.keyedvectors.Vocab at 0x19453198>,
#  '화장독': <gensim.models.keyedvectors.Vocab at 0x19453048>,
#  '전부': <gensim.models.keyedvectors.Vocab at 0x194530b8>,
#  '그론걸': <gensim.models.keyedvectors.Vocab at 0x19453cf8>,
#  '아벤느': <gensim.models.keyedvectors.Vocab at 0x18f13b00>,
#  '미스트': <gensim.models.keyedvectors.Vocab at 0x18f13fd0>,
#  '폼클렌저': <gensim.models.keyedvectors.Vocab at 0x18f13f28>,
#  '크림': <gensim.models.keyedvectors.Vocab at 0x18f13940>,
#  '음주': <gensim.models.keyedvectors.Vocab at 0x18f13b38>,
#  '김채': <gensim.models.keyedvectors.Vocab at 0x18f13eb8>,
#  '스킨케어': <gensim.models.keyedvectors.Vocab at 0x18f13be0>,
#  '피부뒤집어': <gensim.models.keyedvectors.Vocab at 0x18f132e8>,
#  '순간': <gensim.models.keyedvectors.Vocab at 0x18f13860>,
#  '에뛰드': <gensim.models.keyedvectors.Vocab at 0x18f137b8>,
#  '이상': <gensim.models.keyedvectors.Vocab at 0x18f13dd8>,
#  '하이': <gensim.models.keyedvectors.Vocab at 0x18f13978>,
#  '완젼': <gensim.models.keyedvectors.Vocab at 0x18f13828>,
#  '재품': <gensim.models.keyedvectors.Vocab at 0x18f137f0>,
#  '자극인': <gensim.models.keyedvectors.Vocab at 0x18f13550>,
#  '거품재형': <gensim.models.keyedvectors.Vocab at 0x18f133c8>,
#  '계면활성제': <gensim.models.keyedvectors.Vocab at 0x18f135c0>,
#  '성분때문': <gensim.models.keyedvectors.Vocab at 0x18f13400>,
#  '호막': <gensim.models.keyedvectors.Vocab at 0x18f13ac8>,
#  '촉촉': <gensim.models.keyedvectors.Vocab at 0x18f13588>,
#  '클렌저': <gensim.models.keyedvectors.Vocab at 0x18f13f98>,
#  '타입': <gensim.models.keyedvectors.Vocab at 0x18f13128>,
#  '스킨': <gensim.models.keyedvectors.Vocab at 0x18f13f60>,
#  '해주': <gensim.models.keyedvectors.Vocab at 0x18f13e48>,
#  '도움': <gensim.models.keyedvectors.Vocab at 0x18f134a8>,
#  '이루키': <gensim.models.keyedvectors.Vocab at 0x18f13438>,
#  '정남영': <gensim.models.keyedvectors.Vocab at 0x18f13358>,
#  '덕분': <gensim.models.keyedvectors.Vocab at 0x18f13240>,
#  '정상': <gensim.models.keyedvectors.Vocab at 0x18f13198>,
#  '카타': <gensim.models.keyedvectors.Vocab at 0x18f13080>,
#  '이거': <gensim.models.keyedvectors.Vocab at 0x18f13668>,
#  '간접': <gensim.models.keyedvectors.Vocab at 0x18f136a0>,
#  '영상보고따': <gensim.models.keyedvectors.Vocab at 0x18f136d8>,
#  '무변화': <gensim.models.keyedvectors.Vocab at 0x18f13710>,
#  '말씀': <gensim.models.keyedvectors.Vocab at 0x18f13748>,
#  '용도': <gensim.models.keyedvectors.Vocab at 0x18f13780>,
#  '치유': <gensim.models.keyedvectors.Vocab at 0x18f13630>,
#  '영양': <gensim.models.keyedvectors.Vocab at 0x18f135f8>,
#  '수분': <gensim.models.keyedvectors.Vocab at 0x18f13518>,
#  '회복': <gensim.models.keyedvectors.Vocab at 0x18f134e0>,
#  '인거': <gensim.models.keyedvectors.Vocab at 0x18f13470>,
#  '첫번': <gensim.models.keyedvectors.Vocab at 0x18f13320>,
#  '스테': <gensim.models.keyedvectors.Vocab at 0x18f13208>,
#  '이드제': <gensim.models.keyedvectors.Vocab at 0x18f13278>,
#  '세젤비': <gensim.models.keyedvectors.Vocab at 0x18f131d0>,
#  '개지시': <gensim.models.keyedvectors.Vocab at 0x18f13160>,
#  '체감': <gensim.models.keyedvectors.Vocab at 0x18f13048>,
#  '병원다': <gensim.models.keyedvectors.Vocab at 0x18f130b8>,
#  '성피부염': <gensim.models.keyedvectors.Vocab at 0x18f13ef0>,
#  '지금': <gensim.models.keyedvectors.Vocab at 0x18f13d68>,
#  '병원안가': <gensim.models.keyedvectors.Vocab at 0x18f13b70>,
#  '흉터': <gensim.models.keyedvectors.Vocab at 0x188ad550>,
#  '생길거': <gensim.models.keyedvectors.Vocab at 0x188ad048>,
#  '처방': <gensim.models.keyedvectors.Vocab at 0x188ad860>,
#  '이드안': <gensim.models.keyedvectors.Vocab at 0x188ad6a0>}

# %%
## 가장 유사한 단어
model.wv.most_similar('예민')
